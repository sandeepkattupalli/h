# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
movie=pd.read_csv(r"C:\Users\Lenovo\Desktop\movies.csv")
rating=pd.read_csv(r"C:\Users\Lenovo\Desktop\ratings.csv")
tags=pd.read_csv(r"C:\Users\Lenovo\Desktop\tags.csv")
links=pd.read_csv(r"C:\Users\Lenovo\Desktop\links.csv")

# %%
text = pd.read_csv(r"C:\Users\Lenovo\Desktop\README.txt", sep='\t')

# %%
text
# Out:
#                                               Summary
# 0                                             =======
# 1   This dataset (ml-latest-small) describes 5-sta...
# 2   Users were selected at random for inclusion. A...
# 3   The data are contained in the files `links.csv...
# 4   This is a *development* dataset. As such, it m...
# ..                                                ...
# 85  tmdbId is an identifier for movies used by <ht...
# 86  Use of the resources listed above is subject t...
# 87                                   Cross-Validation
# 88                                   ----------------
# 89  Prior versions of the MovieLens dataset includ...
#
# [90 rows x 1 columns]

# %%
tags
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
movie.shape
# Out:
# (9742, 3)

# %%
rating.shape
# Out:
# (100836, 4)

# %%
tags
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
 #How many unique "userId" are available in "ratings.csv"?

# %%
rating
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
data["userId"].unique().shape
# Out:
# (610,)

# %%
#  now am merge in two data sets into an one data set 
data=pd.merge(movie,rating,on=["movieId","movieId"])

# %%
data1=pd.merge(data,tags,on=["movieId","movieId",])

# %%
data1
# Out:
#         movieId                           title  \
# 0             1                Toy Story (1995)
# 1             1                Toy Story (1995)
# 2             1                Toy Story (1995)
# 3             1                Toy Story (1995)
# 4             1                Toy Story (1995)
# ...         ...                             ...
# 233208   187595  Solo: A Star Wars Story (2018)
# 233209   193565       Gintama: The Movie (2010)
# 233210   193565       Gintama: The Movie (2010)
# 233211   193565       Gintama: The Movie (2010)
# 233212   193565       Gintama: The Movie (2010)
#
#                                              genres  userId_x  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 2       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 3       Adventure|Animation|Children|Comedy|Fantasy         5     4.0
# ...

# %%
#Which movie has recieved maximum number of user ratings?
data
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
#data[("userId","movieId")].unique().sum()

# %%
data.columns
# Out:
# Index(['movieId', 'title', 'genres', 'userId', 'rating', 'timestamp'], dtype='object')

# %%
data["userId"].unique().shape
# Out:
# (610,)

# %%
data[['userId', 'movieId']].nunique()
# Out:
# userId      610
# movieId    9724
# dtype: int64

# %%
m = movie.copy()
r = rating.copy()

# %%
#Which movie has recieved maximum number of user ratings?

# %%
data_mr=data.copy()

# %%
data_mr
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
mov_rat=data_mr.groupby('title')

# %%
rat_c = mov_rat.agg(['count'])
rat_c
# Out:
#                                           movieId genres userId rating  \
#                                             count  count  count  count
# title
# '71 (2014)                                      1      1      1      1
# 'Hellboy': The Seeds of Creation (2004)         1      1      1      1
# 'Round Midnight (1986)                          2      2      2      2
# 'Salem's Lot (2004)                             1      1      1      1
# 'Til There Was You (1997)                       2      2      2      2
# ...                                           ...    ...    ...    ...
# eXistenZ (1999)                                22     22     22     22
# xXx (2002)                                     24     24     24     24
# xXx: State of the Union (2005)                  5      5      5      5
# ¡Three Amigos! (1986)                          26     26     26     26
# À nous la liberté (Freedom for Us) (1931)       1      1      1      1
#
# ...

# %%
r_max = rat_c['movieId']

# %%
r_max.sort_values(by='count',ascending=False)
# Out:
#                                            count
# title
# Forrest Gump (1994)                          329
# Shawshank Redemption, The (1994)             317
# Pulp Fiction (1994)                          307
# Silence of the Lambs, The (1991)             279
# Matrix, The (1999)                           278
# ...                                          ...
# King Solomon's Mines (1950)                    1
# King Solomon's Mines (1937)                    1
# King Ralph (1991)                              1
# King Kong Lives (1986)                         1
# À nous la liberté (Freedom for Us) (1931)      1
#
# [9719 rows x 1 columns]

# %%
rrr = r_max.loc[r_max['count']>50]['count']
rrr
# Out:
# title
# 10 Things I Hate About You (1999)     54
# 12 Angry Men (1957)                   57
# 2001: A Space Odyssey (1968)         109
# 28 Days Later (2002)                  58
# 300 (2007)                            80
#                                     ...
# X-Men: The Last Stand (2006)          52
# X2: X-Men United (2003)               76
# Young Frankenstein (1974)             69
# Zombieland (2009)                     53
# Zoolander (2001)                      54
# Name: count, Length: 437, dtype: int64

# %%
tt = tag[['movieId','tag']]
tt
# Out:
#       movieId               tag
# 0       60756             funny
# 1       60756   Highly quotable
# 2       60756      will ferrell
# 3       89774      Boxing story
# 4       89774               MMA
# ...       ...               ...
# 3678     7382         for katie
# 3679     7936           austere
# 3680     3265            gun fu
# 3681     3265  heroic bloodshed
# 3682   168248  Heroic Bloodshed
#
# [3683 rows x 2 columns]

# %%
movie_tags = data1[data1['title'] == 'Matrix, The (1999)']['tag']

movie_tags.unique()
# Out:
# array(['martial arts', 'sci-fi', 'alternate universe', 'philosophy',
#        'post apocalyptic'], dtype=object)

# %%
data1
# Out:
#         movieId                           title  \
# 0             1                Toy Story (1995)
# 1             1                Toy Story (1995)
# 2             1                Toy Story (1995)
# 3             1                Toy Story (1995)
# 4             1                Toy Story (1995)
# ...         ...                             ...
# 233208   187595  Solo: A Star Wars Story (2018)
# 233209   193565       Gintama: The Movie (2010)
# 233210   193565       Gintama: The Movie (2010)
# 233211   193565       Gintama: The Movie (2010)
# 233212   193565       Gintama: The Movie (2010)
#
#                                              genres  userId_x  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 2       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 3       Adventure|Animation|Children|Comedy|Fantasy         5     4.0
# ...

# %%
data
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
unique_values = data[['userId', 'movieId']].nunique()

# %%
unique_values
# Out:
# userId      610
# movieId    9724
# dtype: int64

# %%
aratings = data.groupby('title')['rating'].mean().reset_index(name='average_rating')

# %%
aratings
# Out:
#                                           title  average_rating
# 0                                    '71 (2014)        4.000000
# 1       'Hellboy': The Seeds of Creation (2004)        4.000000
# 2                        'Round Midnight (1986)        3.500000
# 3                           'Salem's Lot (2004)        5.000000
# 4                     'Til There Was You (1997)        4.000000
# ...                                         ...             ...
# 9714                            eXistenZ (1999)        3.863636
# 9715                                 xXx (2002)        2.770833
# 9716             xXx: State of the Union (2005)        2.000000
# 9717                      ¡Three Amigos! (1986)        3.134615
# 9718  À nous la liberté (Freedom for Us) (1931)        1.000000
#
# [9719 rows x 2 columns]

# %%
#popular = average_ratings.loc[aratings['arating'].idxmax()]['movieId']
# Assuming average_ratings is your DataFrame with the column 'average_rating'
popular = average_ratings.loc[average_ratings['average_rating'].idxmax()]['title']

print(f"The most popular movie based on average user ratings is: {popular}")
# Out:
# The most popular movie based on average user ratings is: Come and See (Idi i smotri) (1985)

# %%
# Assuming average_ratings is your DataFrame with the column 'average_rating'
most_popular_movie = average_ratings.loc[average_ratings['average_rating'].idxmax()]['MovieTitle']

print(f"The most popular movie based on average user ratings is: {most_popular_movie}")

# %%
# Assuming data1 is your DataFrame
# Applying mandatory operations
unique_values = data[['userId', 'movieId']].nunique()
values = unique_values_count.sum()

# Group by movie title and calculate the average user rating
aratings = data1.groupby('title')['rating'].mean().reset_index(name='average_rating')

# Find the movie with the highest average rating
popular = average_ratings.loc[average_ratings['average_rating'].idxmax()]['movieId']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\sandeep kattupalli\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\sandeep kattupalli\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\sandeep kattupalli\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'movieId'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Assuming r is your DataFrame
# Applying mandatory operations
unique_values_count = data1[['userId', 'movieId']].nunique()
total_unique_values = unique_values_count.sum()

# Group by movie title and calculate the average user rating
average_ratings = data1.groupby('title')['rating'].mean().reset_index(name='average_rating')

# Find the movie with the highest average rating
most_popular_movie = average_ratings.loc[average_ratings['average_rating'].idxmax()]['title']

print(f"The most popular movie based on average user ratings is: {most_popular_movie}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[109], line 3
#       1 # Assuming r is your DataFrame
#       2 # Applying mandatory operations
# ----> 3 unique_values_count = data1[['userId', 'movieId']].nunique()
#       4 total_unique_values = unique_values_count.sum()
#       6 # Group by movie title and calculate the average user rating
#
# File ~\anaconda3\sandeep kattupalli\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\sandeep kattupalli\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
# ...

# %%
t = mov.merge(tt,on='movieId',how='inner')

# %%
t
# Out:
#       movieId                           title  \
# 0           1                Toy Story (1995)
# 1           1                Toy Story (1995)
# 2           1                Toy Story (1995)
# 3           2                  Jumanji (1995)
# 4           2                  Jumanji (1995)
# ...       ...                             ...
# 3678   187595  Solo: A Star Wars Story (2018)
# 3679   193565       Gintama: The Movie (2010)
# 3680   193565       Gintama: The Movie (2010)
# 3681   193565       Gintama: The Movie (2010)
# 3682   193565       Gintama: The Movie (2010)
#
#                                            genres               tag
# 0     Adventure|Animation|Children|Comedy|Fantasy             pixar
# 1     Adventure|Animation|Children|Comedy|Fantasy             pixar
# 2     Adventure|Animation|Children|Comedy|Fantasy               fun
# 3                      Adventure|Children|Fantasy           fantasy
# ...

# %%
t.loc[t['title'] == "Matrix, The (1999)"]
# Out:
#       movieId               title                  genres                 tag
# 1313     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller        martial arts
# 1314     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller              sci-fi
# 1315     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller  alternate universe
# 1316     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller          philosophy
# 1317     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller    post apocalyptic

# %%
data_mr.loc[data_mr['title']=="Terminator 2: Judgment Day (1991)"]['rating'].mean()
# Out:
# 3.970982142857143

# %%
dist = data_mr.loc[data_mr['title']=="Fight Club (1999)"]
dist
# Out:
#        movieId              title                       genres  userId  \
# 49835     2959  Fight Club (1999)  Action|Crime|Drama|Thriller       1
# 49836     2959  Fight Club (1999)  Action|Crime|Drama|Thriller       4
# 49837     2959  Fight Club (1999)  Action|Crime|Drama|Thriller      10
# 49838     2959  Fight Club (1999)  Action|Crime|Drama|Thriller      15
# 49839     2959  Fight Club (1999)  Action|Crime|Drama|Thriller      16
# ...        ...                ...                          ...     ...
# 50048     2959  Fight Club (1999)  Action|Crime|Drama|Thriller     601
# 50049     2959  Fight Club (1999)  Action|Crime|Drama|Thriller     603
# 50050     2959  Fight Club (1999)  Action|Crime|Drama|Thriller     606
# 50051     2959  Fight Club (1999)  Action|Crime|Drama|Thriller     608
# 50052     2959  Fight Club (1999)  Action|Crime|Drama|Thriller     610
#
#        rating   timestamp
# 49835     5.0   964983282
# 49836     2.0   945078528
# 49837     0.5  1455356582
# ...

# %%
sns.kdeplot(data=dist,x='rating')
# Out:
# <Axes: xlabel='rating', ylabel='Density'>

# %%
avg_rat = mov_rat.agg(['mean'])
avg_rat
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_10184\1460533694.py:1: FutureWarning: ['genres'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   avg_rat = mov_rat.agg(['mean'])
#                                             movieId      userId    rating  \
#                                                mean        mean      mean
# title
# '71 (2014)                                 117867.0  610.000000  4.000000
# 'Hellboy': The Seeds of Creation (2004)     97757.0  332.000000  4.000000
# 'Round Midnight (1986)                      26564.0  354.500000  3.500000
# 'Salem's Lot (2004)                         27751.0  345.000000  5.000000
# 'Til There Was You (1997)                     779.0  229.000000  4.000000
# ...                                             ...         ...       ...
# eXistenZ (1999)                              2600.0  389.954545  3.863636
# ...

# %%
avg_r = avg_rat['rating']

# %%
avg_r.sort_values(by='mean',ascending=False).head()
# Out:
#                                      mean
# title
# Gena the Crocodile (1969)             5.0
# True Stories (1986)                   5.0
# Cosmic Scrat-tastrophe (2015)         5.0
# Love and Pigeons (1985)               5.0
# Red Sorghum (Hong gao liang) (1987)   5.0

# %%
gene = data_mr.groupby('genres')

# %%
gene.agg(['count'])
# Out:
#                                     movieId title userId rating timestamp
#                                       count count  count  count     count
# genres
# (no genres listed)                       47    47     47     47        47
# Action                                  186   186    186    186       186
# Action|Adventure                        555   555    555    555       555
# Action|Adventure|Animation               42    42     42     42        42
# Action|Adventure|Animation|Children      39    39     39     39        39
# ...                                     ...   ...    ...    ...       ...
# Sci-Fi|Thriller                         116   116    116    116       116
# Sci-Fi|Thriller|IMAX                     12    12     12     12        12
# Thriller                                628   628    628    628       628
# War                                       9     9      9      9         9
# Western                                 151   151    151    151       151
#
# ...

# %%
sci = data_mr.loc[(data_mr['genres']=='Sci-Fi')]
sci
# Out:
#         movieId                                  title  genres  userId  \
# 41853      2311  2010: The Year We Make Contact (1984)  Sci-Fi      27
# 41854      2311  2010: The Year We Make Contact (1984)  Sci-Fi      42
# 41855      2311  2010: The Year We Make Contact (1984)  Sci-Fi      45
# 41856      2311  2010: The Year We Make Contact (1984)  Sci-Fi      57
# 41857      2311  2010: The Year We Make Contact (1984)  Sci-Fi     182
# ...         ...                                    ...     ...     ...
# 100589   176371               Blade Runner 2049 (2017)  Sci-Fi     515
# 100590   176371               Blade Runner 2049 (2017)  Sci-Fi     567
# 100591   176371               Blade Runner 2049 (2017)  Sci-Fi     586
# 100592   176371               Blade Runner 2049 (2017)  Sci-Fi     599
# 100593   176371               Blade Runner 2049 (2017)  Sci-Fi     601
#
#         rating   timestamp
# 41853      2.0   965151086
# 41854      4.0   996259554
# 41855      4.0   950740918
# ...

# %%
scii = sci.groupby('title')

# %%
scii.agg(['count'])
# Out:
#                                                    movieId genres userId  \
#                                                      count  count  count
# title
# 20 Million Miles to Earth (1957)                         1      1      1
# 2010: The Year We Make Contact (1984)                   17     17     17
# Alien from L.A. (1988)                                   1      1      1
# Amazing Transparent Man, The (1960)                      1      1      1
# Android (1982)                                           2      2      2
# Angry Red Planet, The (1959)                             1      1      1
# Arrival (2016)                                          26     26     26
# Babylon 5                                                2      2      2
# Babylon 5: The Gathering (1993)                          1      1      1
# Babylon 5: The Legend of the Rangers: To Live a...       1      1      1
# Babylon 5: The Lost Tales - Voices in the Dark ...       1      1      1
# ...

# %%
# Assuming your DataFrame is named 'movies' and contains a column 'imdb_rating'
highest_imdb_movie = movie.loc[movie['rating'].idxmax()]['movieId']

print(f"The movieId of the movie with the highest IMDb rating is: {highest_imdb_movie}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\sandeep kattupalli\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\sandeep kattupalli\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\sandeep kattupalli\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'rating'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Assuming your DataFrame is named 'movies' and contains a column 'imdb_rating'
highest_imdb_movie = movies.loc[movies['rating'].idxmax()]['movieId']

print(f"The movieId of the movie with the highest IMDb rating is: {highest_imdb_movie}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[128], line 2
#       1 # Assuming your DataFrame is named 'movies' and contains a column 'imdb_rating'
# ----> 2 highest_imdb_movie = movies.loc[movies['rating'].idxmax()]['movieId']
#       4 print(f"The movieId of the movie with the highest IMDb rating is: {highest_imdb_movie}")
#
# NameError: name 'movies' is not defined

# %%
scifi_movies_sorted = scifi_movies.sort_values(by='number of ratings', ascending=False)

third_most_popular_scifi = scifi_movies_sorted.iloc[2]  

third_most_popular_scifi_title = third_most_popular_scifi['title']
third_most_popular_scifi_movie_id = third_most_popular_scifi['movieId']

print(f"The third most popular Sci-Fi movie is '{third_most_popular_scifi_title}' with movie ID: {third_most_popular_scifi_movie_id}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 scifi_movies_sorted = scifi_movies.sort_values(by='number of ratings', ascending=False)
#       3 third_most_popular_scifi = scifi_movies_sorted.iloc[2]
#       5 third_most_popular_scifi_title = third_most_popular_scifi['title']
#
# NameError: name 'scifi_movies' is not defined
